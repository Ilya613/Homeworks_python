# %% [markdown]
#                                                    בסייד

# %% [markdown]
# Задание 1

# %%
import pandas as pd

log = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Pandas/Pandas3/dop_material/visit_log.csv', sep=';')

log.loc[((log['traffic_source'] == 'yandex') | (log['traffic_source'] == 'google')) , 'source_type'] = 'organic'
log.loc[(((log.traffic_source == 'paid') | (log.traffic_source == 'email')) & (log['region'] == 'Russia')), 'source_type'] = 'ad'
log.loc[(((log.traffic_source == 'paid') | (log.traffic_source == 'email')) & (log['region'] != 'Russia')), 'source_type'] = 'other'
log.loc[pd.isnull(log.source_type), 'source_type'] = log.traffic_source

log.head(30)

# %% [markdown]
# Задание 2

# %%
urls = pd.read_table('/content/drive/MyDrive/Colab Notebooks/Pandas/Pandas3/dop_material/URLs.txt')

urls[urls.url.str.contains(r'/\d{8}-')]

# %% [markdown]
# Задание 3

# %%
ratings = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Pandas/Pandas3/dop_material/ml-latest-small/ratings.csv', sep=',')

df = ratings.groupby('userId').agg({'timestamp': ['min', 'max'], 'rating': 'count'})
result_df = df.loc[result[('rating', 'count')] > 100]
result_df['time_of_life_day'] = round((result_df[('timestamp', 'max')] - result_df[('timestamp', 'min')])/(60*60*24), 1)
result_df.sort_values('time_of_life_day', ascending=False).head(10)

# %% [markdown]
# Задание 4

# %%
rzd = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115],
        'rzd_revenue': [1093, 2810, 10283, 5774, 981]
    }
)

auto = pd.DataFrame(
    {
        'client_id': [113, 114, 115, 116, 117],
        'auto_revenue': [57483, 83, 912, 4834, 98]
    }
)

air = pd.DataFrame(
    {
        'client_id': [115, 116, 117, 118],
        'air_revenue': [81, 4, 13, 173]
    }
)

client_base = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115, 116, 117, 118],
        'address': ['Комсомольская 4', 'Энтузиастов 8а', 'Левобережная 1а', 'Мира 14', 'ЗЖБИиДК 1', 
                    'Строителей 18', 'Панфиловская 33', 'Мастеркова 4']
    }
)

# %%
df1 = client_base.merge(rzd, how='left', on='client_id')
df2 = df1.merge(auto, how='left', on='client_id')
result_df1 = df2.merge(air, how='left', on='client_id')
result_df2 = result_df1.drop('address', axis=1)

# %%
result_df1
# Out:
#    client_id          address  rzd_revenue  auto_revenue  air_revenue
# 0        111  Комсомольская 4       1093.0           NaN          NaN
# 1        112   Энтузиастов 8а       2810.0           NaN          NaN
# 2        113  Левобережная 1а      10283.0       57483.0          NaN
# 3        114          Мира 14       5774.0          83.0          NaN
# 4        115        ЗЖБИиДК 1        981.0         912.0         81.0
# 5        116    Строителей 18          NaN        4834.0          4.0
# 6        117  Панфиловская 33          NaN          98.0         13.0
# 7        118     Мастеркова 4          NaN           NaN        173.0
